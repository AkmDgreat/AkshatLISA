# %%
import os as os
import sys
import numpy as np

# adding folders to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd()  , '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

akshat_lisa_root = os.path.abspath(os.path.join(os.getcwd()  , '..',))
if akshat_lisa_root not in sys.path:
    sys.path.insert(0, akshat_lisa_root)

from scripts.psdNoiseHistogram import compute_psd_noise_distribution, plot_psd_noise_histogram
from scripts.multipleNoisePSD import compute_noise_psds, plot_noise_psds
import matplotlib.pyplot as plt

# %%
bethLISA_directory = os.path.join(os.getcwd(), "..", "..", "bethLISA")
tdi_path = os.path.join(bethLISA_directory, 'lisa_glitch_simulation',
                        'tdi_outputs', 'vsmall_glitch_tdi.h5')

# %%
freq, orig_psd, ensemble = compute_noise_psds(
    tdi_file_path=tdi_path,
    n_trials=1000,
    window='hann',
    nper=17000
)

plot_noise_psds(freq, orig_psd, ensemble, n_to_plot=5)

# %%
ensemble_np = np.array(ensemble)
print(ensemble_np.shape)
# len(ensemble)
ensemble_mean = ensemble_np.mean(axis=0)
print(ensemble_mean.shape)

print(freq.shape)
plt.loglog(freq, ensemble_mean)
# ax.set_xlim(f_min, f_max)
# plt.set_xlabel("Frequency [Hz]")
# plt.set_ylabel("PSD [1/Hz]")
# plt.set_title("WOSA (log-log)")

# %%
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.3,
    n_trials=100
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.9,
    n_trials=100
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50, title="Noise PSD distribution, 100 trials")

# %%
# WARNING: takes long time to run
# noise_vals, orig_psd, freq = compute_psd_noise_distribution(
#     tdi_file_path = tdi_path,
#     fraction=0.9,
#     n_trials=1000
# )

# plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50, title="Noise PSD distribution, 1000 trials")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 noise_vals, orig_psd, freq = compute_psd_noise_distribution(
#       2     tdi_file_path = tdi_path,
#       3     fraction=0.9,
#       4     n_trials=1000
#       5 )
#       7 plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50, title="Noise PSD distribution, 1000 trials")
#
# File ~/Desktop/LISA/lisa_code/AkshatLISA/scripts/psdNoiseHistogram.py:67, in compute_psd_noise_distribution(tdi_file_path, channel, fraction, n_trials, window, nper, noverlap, average, scaling, seed_offset)
#      65 noise_vals = np.empty(n_trials)
#      66 for i in range(n_trials):
# ---> 67     _, _, psd_noise = psdTdiNoise(
#      68         tdi_file_path=tdi_file_path,
#      69         channel=channel,
#      70         window=window,
#      71         nper=nper,
#      72         noverlap=noverlap,
# ...

# %%
freq, orig_psd, ensemble = compute_noise_psds(
    tdi_file_path=tdi_path,
    n_trials=100,
    window='hann',
    nper=4096
)
plot_noise_psds(freq, orig_psd, ensemble, n_to_plot=5)

# %%
bethLISA_directory = os.path.join(os.getcwd(), "..", "..", "bethLISA")
tdi_path = os.path.join(bethLISA_directory, 'lisa_glitch_simulation',
                        'tdi_outputs', 'vsmall_glitch_tdi.h5')

# %%
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.3,
    n_trials=100,
    nper = 2000,
    noverlap = 1000
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
nper = 4096
noverlap = (int) (0.1 * nper)
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.3,
    n_trials=1000,
    nper = nper,
    noverlap = noverlap
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
nper = 2000
noverlap = (int) (0.1 * nper)
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.3,
    n_trials=1000,
    nper = nper,
    noverlap = noverlap
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
nper = 500
noverlap = (int) (0.1 * nper)
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.6,
    n_trials=1000,
    nper = nper,
    noverlap = noverlap
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %% [markdown]
# The following code is using the new-chatgpt-method

# %%
## This one is newere one (hopefully )
nper = 500
noverlap = (int) (0.1 * nper)
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.95,
    n_trials=1000,
    nper = nper,
    noverlap = noverlap
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
## This one is newere one (hopefully )
nper = 500
noverlap = (int) (0.1 * nper)
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.6,
    n_trials=1000,
    nper = nper,
    noverlap = noverlap
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
## This one is newere one (hopefully )
nper = 500
noverlap = (int) (0.1 * nper)
noise_vals, orig_psd, freq = compute_psd_noise_distribution(
    tdi_file_path = tdi_path,
    fraction=0.9,
    n_trials=1000,
    nper = nper,
    noverlap = noverlap
)

plot_psd_noise_histogram(noise_vals, orig_psd, freq, n_bins=50)

# %%
freq, orig_psd, ensemble = compute_noise_psds(
    tdi_file_path=tdi_path,
    n_trials=100,
    window='hann',
    nper=4096
)
plot_noise_psds(freq, orig_psd, ensemble, n_to_plot=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 freq, orig_psd, ensemble = compute_noise_psds(
#       2     tdi_file_path=tdi_path,
#       3     n_trials=100,
#       4     window='hann',
#       5     nper=4096
#       6 )
#       7 plot_noise_psds(freq, orig_psd, ensemble, n_to_plot=5)
#
# File ~/Desktop/LISA/lisa_code/AkshatLISA/scripts/multipleNoisePSD.py:31, in compute_noise_psds(tdi_file_path, channel, n_trials, window, nper, noverlap, average, scaling, seed_offset)
#      18 """
#      19 Computes the true PSD and an ensemble of noise-only PSDs.
#      20
#    (...)
#      28     List of noise-only PSD arrays (length n_trials).
#      29 """
#      30 # Compute the true PSD and initialize ensemble
# ---> 31 psd_orig, freq, _ = psdTdiNoise(
#      32     tdi_file_path=tdi_file_path,
#      33     channel=channel,
# ...

# %%
freq, orig_psd, ensemble = compute_noise_psds(
    tdi_file_path=tdi_path,
    n_trials=100,
    window='hann',
    nper=4096
)
plot_noise_psds(freq, orig_psd, ensemble, n_to_plot=10)
