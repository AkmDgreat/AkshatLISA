# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import simpson
from scipy.stats import chi2

# %%
s = 1
N = 10
x = np.linspace(0, 50*s, 20000)    
pdf_mean = ((x/s) ** (N-1)) * np.exp(-x/(2 * s))
pdf_mean /= simpson(pdf_mean, x=x)

pdf_mean_chi2 = chi2.pdf(x, 20)
plt.plot(x, pdf_mean_chi2, label="scipy chi2")
plt.plot(x, pdf_mean, label=f'Chi 2')
plt.legend()
plt.show()
