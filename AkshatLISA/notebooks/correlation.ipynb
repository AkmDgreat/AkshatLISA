# %%
import os as os
import sys

# adding folders to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd()  , '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

akshat_lisa_root = os.path.abspath(os.path.join(os.getcwd()  , '..',))
if akshat_lisa_root not in sys.path:
    sys.path.insert(0, akshat_lisa_root)

from scripts.correlation import compute_psd_noise_pair, plot_psd_noise_correlation
import matplotlib.pyplot as plt
# Out:
# /Users/akmdgreat/anaconda3/envs/bethenv/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS

# %%
bethLISA_directory = os.path.join(os.getcwd(), "..", "..", "bethLISA")
tdi_path = os.path.join(bethLISA_directory, 'lisa_glitch_simulation',
                        'tdi_outputs', 'vsmall_glitch_tdi.h5')

# %%
noise1, noise2, f1, f2 = compute_psd_noise_pair(
    tdi_file_path=tdi_path,
    fraction=0.8,
    offset_bins=1,
    n_trials=100,
    window='hann',
    nper=4096
)
plot_psd_noise_correlation(noise1, noise2, f1, f2, title="PSD Noise Correlation, 1 bin apart")

# %%
noise1, noise2, f1, f2 = compute_psd_noise_pair(
    tdi_file_path=tdi_path,
    fraction=0.8,
    offset_bins=10,
    n_trials=100,
    window='hann',
    nper=4096
)
plot_psd_noise_correlation(noise1, noise2, f1, f2, title="PSD Noise Correlation, 10 bins apart")

# %%
noise1, noise2, f1, f2 = compute_psd_noise_pair(
    tdi_file_path=tdi_path,
    fraction=0.8,
    offset_bins=100,
    n_trials=100,
    window='hann',
    nper=4096
)
plot_psd_noise_correlation(noise1, noise2, f1, f2, title="PSD Noise Correlation, 100 bins apart")
