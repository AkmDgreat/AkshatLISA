# %% [markdown]
# ### Trying out different windows
#
# I try out different windowing functions (Hann, Hamm, Kaiser, Nuttal ...), and seee how they be lookin' with and without glitch

# %%
import os as os
import sys

# adding folders to sys.path
project_root = os.path.abspath(os.path.join(os.getcwd()  , '..', '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

akshat_lisa_root = os.path.abspath(os.path.join(os.getcwd()  , '..',))
if akshat_lisa_root not in sys.path:
    sys.path.insert(0, akshat_lisa_root)

import matplotlib.pyplot as plt
from scripts.wosa import wosa
from scripts.psdAndPlot import psd_and_plot_hor
from scripts.psdAndPlotTDI import psdAndPlotTDI
import numpy as np
# Out:
# /Users/akmdgreat/anaconda3/envs/bethenv/lib/python3.11/site-packages/gwpy/time/__init__.py:36: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import LIGOTimeGPS

# %%
# Synthetic example: 10 Hz sine in white Gaussian noise
fs = 1000          # Hz
t  = np.arange(0, 5, 1/fs)
dt = t[1] - t[0]
nper = 256
sig = 0.5*np.sin(2*np.pi*10*t) + 0.2*np.random.randn(t.size)

noverlap = (int) (0.5 * nper)
window = 'hann'

psd_and_plot_hor(
    data = sig, 
    t = t, 
    dt = dt, 
    nper = 256, 
    window = window, 
    noverlap = noverlap,
    scaling = 'density', 
    custom_wosa=True,
    average="mean",
    title = "Sine signal", 
)

window='nuttall'
noverlap = (int) (0.656 * nper)

psd_and_plot_hor(
    data = sig, 
    t = t, 
    dt = dt, 
    nper = 256, 
    window = window, 
    noverlap = noverlap,
    scaling = 'density', 
    custom_wosa=True,
    average="mean",
    title = "Sine signal", 
)
# Out:
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa

# %%
mean = 0
std = 1 
num_samples = 10000
whiteNoise = np.random.normal(mean, std, size=num_samples)

t   = np.arange(num_samples)
data = whiteNoise
dt  = 1
psd_and_plot_hor(data, t, dt, nper=256, title="White noise", custom_wosa=True, average="mean")
psd_and_plot_hor(data, t, dt, nper=256, title="White noise", custom_wosa=True, average="median")
# Out:
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa

# %%
bethLISA_directory = os.path.join(os.getcwd(), "..", "..", "bethLISA")
glitch_simulation_directory = os.path.join(bethLISA_directory, 'lisa_glitch_simulation')
tdi_output_directory = os.path.join(glitch_simulation_directory, 'tdi_outputs')

nper = 4096
nover_han = (int) (0.5 * nper)
nover_nut = (int) (0.656 * nper)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "vsmall_glitch_tdi.h5"),
    custom_wosa = True,
    average="mean",
    window="hann",
    noverlap = nover_han,
    bigtitle="Very Small Glitch, Hannings, Mean"
)
psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "vsmall_glitch_tdi.h5"),
    custom_wosa = True,
    average="mean",
    window="nuttall",
    noverlap=nover_nut,
    bigtitle="Very small Glitch, Nuttall, Mean"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "vsmall_glitch_tdi.h5"),
    custom_wosa = True,
    average="median",
    window="hann",
    noverlap = nover_han,
    bigtitle="Very small Glitch, Hannings, Median"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "vsmall_glitch_tdi.h5"),
    custom_wosa = True,
    average="median",
    window="nuttall",
    noverlap=nover_nut,
    bigtitle="Very small Glitch, Nuttall, Median"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "large_glitch_tdi.h5"),
    custom_wosa = True,
    average="mean",
    window="hann",
    noverlap = nover_han,
    bigtitle="Large Glitch, Hannings, Mean"
)
psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "large_glitch_tdi.h5"),
    custom_wosa = True,
    average="mean",
    window="nuttall",
    noverlap=nover_nut,
    bigtitle="Large Glitch, Nuttall, Mean"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "large_glitch_tdi.h5"),
    custom_wosa = True,
    average="median",
    window="hann",
    noverlap = nover_han,
    bigtitle="Large Glitch, Hannings, Median"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "large_glitch_tdi.h5"),
    custom_wosa = True,
    average="median",
    window="nuttall",
    noverlap=nover_nut,
    bigtitle="Large Glitch, Nuttall, Median"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "large_glitch_tdi.h5"),
    custom_wosa = True,
    average="median",
    window="nuttall",
    bigtitle="Large Glitch, Nuttall, Median, 50 percent overlap"
)

psdAndPlotTDI(
    tdi_file_path = os.path.join(tdi_output_directory, "vsmall_glitch_tdi.h5"),
    custom_wosa = True,
    average="mean",
    window="hann",
    noverlap = nover_han,
    bigtitle="Very Small Glitch, Hannings, Mean"
)
# Out:
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
# Custom WOSA yooohoo
# Exiting custom wosa
